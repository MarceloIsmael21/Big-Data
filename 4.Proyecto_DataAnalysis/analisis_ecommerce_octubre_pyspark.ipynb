# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, when, isnan, lit, desc, hour, dayofmonth, dayofweek
from pyspark.sql.functions import split, regexp_extract
from pyspark.sql.types import DoubleType, FloatType

spark = SparkSession.builder \
    .appName("Analisis Ecommerce Octubre") \
    .config("spark.driver.memory", "6g") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://WGC1HM7P656F3.Hermosillo.ford.com:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Analisis Ecommerce Octubre</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
root=".."
file_path = root + "/datasets/2019-Oct.csv"

df = spark.read.option("header", True) \
               .option("inferSchema", True) \
               .csv(file_path)

df.show(5, truncate=False)
# Out:
# +-------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# |event_time         |event_type|product_id|category_id        |category_code                      |brand   |price  |user_id  |user_session                        |
# +-------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# |2019-09-30 17:00:00|view      |44600062  |2103807459595387724|NULL                               |shiseido|35.79  |541312140|72d76fde-8bb3-4e00-8c23-a032dfed738c|
# |2019-09-30 17:00:00|view      |3900821   |2053013552326770905|appliances.environment.water_heater|aqua    |33.2   |554748717|9333dfbd-b87a-4708-9857-6336556b0fcc|
# |2019-09-30 17:00:01|view      |17200506  |2053013559792632471|furniture.living_room.sofa         |NULL    |543.1  |519107250|566511c2-e2e3-422b-b695-cf8e6e792ca8|
# |2019-09-30 17:00:01|view      |1307067   |2053013558920217191|computers.notebook                 |lenovo  |251.74 |550050854|7c90fc70-0e80-4590-96f3-13c02c18c713|
# |2019-09-30 17:00:04|view      |1004237   |2053013555631882655|electronics.smartphone             |apple   |1081.98|535871217|c6bd7419-2748-4c56-95b4-8cec9ff8b80d|
# +-------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- event_time: timestamp (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- category_id: long (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- user_id: integer (nullable = true)
#  |-- user_session: string (nullable = true)

# %% [markdown]
# ## Estadísticas

# %%
#Numero de registros y columnas 
num_rows = df.count()
num_cols = len(df.columns)

print(f"Número de registros: {num_rows:,}")
print(f"Número de columnas: {num_cols}")
# Out:
# Número de registros: 42,448,764
# Número de columnas: 9

# %%
#Estadísticas de variable precio
df.select("price").describe().show()
price_percentiles = df.approxQuantile("price", [0.25, 0.5, 0.75], 0.01)

print("Percentil 25:", price_percentiles[0])
print("Mediana:", price_percentiles[1])
print("Percentil 75:", price_percentiles[2])
# Out:
# +-------+-----------------+
# |summary|            price|
# +-------+-----------------+
# |  count|         42448764|
# |   mean|290.3236606848809|
# | stddev|358.2691553394021|
# |    min|              0.0|
# |    max|          2574.07|
# +-------+-----------------+
#
# Percentil 25: 64.78
# Mediana: 161.83
# Percentil 75: 357.77

# %%
#Frecuencia de event_type
event_type_counts = df.groupBy("event_type") \
                      .count() \
                      .withColumn("percentage", (col("count") / lit(num_rows)) * 100) \
                      .orderBy(desc("count"))

event_type_counts.show(truncate=False)
# Out:
# +----------+--------+------------------+
# |event_type|count   |percentage        |
# +----------+--------+------------------+
# |view      |40779399|96.06734132470854 |
# |cart      |926516  |2.182668970055288 |
# |purchase  |742849  |1.7499897052361761|
# +----------+--------+------------------+

# %%
#Valores faltantes por columna 
from pyspark.sql.functions import col, count, when, isnan
import pandas as pd

# Número total de registros
num_rows = df.count()

# Crear expresiones para contar valores faltantes
missing_exprs = []

for c, dtype in df.dtypes:
    if dtype in ["double", "float"]:
        missing_exprs.append(
            count(when(col(c).isNull() | isnan(col(c)), c)).alias(c)
        )
    else:
        missing_exprs.append(
            count(when(col(c).isNull(), c)).alias(c)
        )

# Ejecutar conteo de nulos
missing_result = df.select(missing_exprs).collect()[0].asDict()

# Convertir a Pandas para evitar error de Python worker en Spark
missing_summary_pd = pd.DataFrame(
    list(missing_result.items()),
    columns=["variable", "missing_values"]
)

missing_summary_pd["missing_percentage"] = (
    missing_summary_pd["missing_values"] / num_rows
) * 100

missing_summary_pd = missing_summary_pd.sort_values(
    by="missing_percentage",
    ascending=False
)

missing_summary_pd
# Out:
#         variable  missing_values  missing_percentage
# 4  category_code        13515609           31.839818
# 5          brand         6113008           14.400909
# 8   user_session               2            0.000005
# 0     event_time               0            0.000000
# 1     event_type               0            0.000000
# 3    category_id               0            0.000000
# 2     product_id               0            0.000000
# 6          price               0            0.000000
# 7        user_id               0            0.000000

# %%
#Valores únicos por variable
columns_to_check = ["product_id", "category_id", "category_code", "brand", "user_id", "user_session"]

for c in columns_to_check:
    print(f"{c}: {df.select(c).distinct().count():,} valores únicos")
# Out:
# product_id: 166,794 valores únicos
# category_id: 624 valores únicos
# category_code: 127 valores únicos
# brand: 3,446 valores únicos
# user_id: 3,022,290 valores únicos
# user_session: 9,244,422 valores únicos

# %%
#Categorías más frecuentes
df.groupBy("category_code") \
  .count() \
  .withColumn("percentage", (col("count") / lit(num_rows)) * 100) \
  .orderBy(desc("count")) \
  .show(20, truncate=False)
# Out:
# +--------------------------------+--------+------------------+
# |category_code                   |count   |percentage        |
# +--------------------------------+--------+------------------+
# |NULL                            |13515609|31.839817526842477|
# |electronics.smartphone          |11507231|27.108518401148263|
# |electronics.clocks              |1311033 |3.088506887974406 |
# |computers.notebook              |1137623 |2.6799908708767117|
# |electronics.video.tv            |1113750 |2.623751306398462 |
# |electronics.audio.headphone     |1100188 |2.591802201826183 |
# |appliances.kitchen.refrigerators|887755  |2.0913565351396333|
# |appliances.kitchen.washer       |869404  |2.04812559442249  |
# |appliances.environment.vacuum   |801670  |1.888559110931946 |
# |apparel.shoes                   |763901  |1.7995836109621473|
# |auto.accessories.player         |470208  |1.1077071643358096|
# |computers.desktop               |424242  |0.9994213259071572|
# |apparel.shoes.keds              |410304  |0.9665864476054004|
# |furniture.bedroom.bed           |358453  |0.8444368368417041|
# |electronics.tablet              |316735  |0.7461583569311936|
# |electronics.audio.subwoofer     |313664  |0.7389237528800603|
# |furniture.living_room.cabinet   |301410  |0.7100560101113899|
# |construction.tools.drill        |279948  |0.6594962340952967|
# |electronics.telephone           |247628  |0.5833573858593386|
# |auto.accessories.videoregister  |224076  |0.5278740271448187|
# +--------------------------------+--------+------------------+
# only showing top 20 rows

# %%
#Marcas más frecuentes
df.groupBy("brand") \
  .count() \
  .withColumn("percentage", (col("count") / lit(num_rows)) * 100) \
  .orderBy(desc("count")) \
  .show(20, truncate=False)
# Out:
# +--------+-------+------------------+
# |brand   |count  |percentage        |
# +--------+-------+------------------+
# |NULL    |6113008|14.400909293848931|
# |samsung |5282775|12.44506200463222 |
# |apple   |4122554|9.711835190301418 |
# |xiaomi  |3083763|7.264670886530407 |
# |huawei  |1111205|2.617755843256119 |
# |lucente |655861 |1.5450650106090251|
# |lg      |562404 |1.3249007674287054|
# |bosch   |557090 |1.3123821461562462|
# |oppo    |482887 |1.1375761141125333|
# |sony    |456644 |1.0757533482011397|
# |acer    |428153 |1.008634786162443 |
# |cordiant|368277 |0.8675800313055051|
# |artel   |338203 |0.7967322676344593|
# |lenovo  |338103 |0.7964966895149174|
# |hp      |305242 |0.7190833636522372|
# |indesit |290101 |0.6834144805723907|
# |dauscher|289853 |0.6828302468359266|
# |philips |282699 |0.6659769881638956|
# |redmond |279734 |0.6589920969194769|
# |respect |271167 |0.638810119418318 |
# +--------+-------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Particionamiento

# %%
from pyspark.sql.functions import (
    col, when, hour, split, lit, desc, count, coalesce
)

# %%
df_part = df

# %%
df_part = df_part.withColumn(
    "category_group",
    when(
        col("category_code").isNull(), 
        "unknown"
    ).otherwise(
        split(col("category_code"), "\\.").getItem(0)
    )
)

df_part.select("category_code", "category_group").show(10, truncate=False)
# Out:
# +-----------------------------------+--------------+
# |category_code                      |category_group|
# +-----------------------------------+--------------+
# |NULL                               |unknown       |
# |appliances.environment.water_heater|appliances    |
# |furniture.living_room.sofa         |furniture     |
# |computers.notebook                 |computers     |
# |electronics.smartphone             |electronics   |
# |computers.desktop                  |computers     |
# |NULL                               |unknown       |
# |NULL                               |unknown       |
# |apparel.shoes.keds                 |apparel       |
# |electronics.smartphone             |electronics   |
# +-----------------------------------+--------------+
# only showing top 10 rows

# %%
df_part = df_part.withColumn(
    "event_hour",
    hour(col("event_time"))
)

df_part = df_part.withColumn(
    "time_period",
    when((col("event_hour") >= 0) & (col("event_hour") <= 5), "night")
    .when((col("event_hour") >= 6) & (col("event_hour") <= 11), "morning")
    .when((col("event_hour") >= 12) & (col("event_hour") <= 17), "afternoon")
    .when((col("event_hour") >= 18) & (col("event_hour") <= 23), "evening")
    .otherwise("unknown")
)

df_part.select("event_time", "event_hour", "time_period").show(10, truncate=False)
# Out:
# +-------------------+----------+-----------+
# |event_time         |event_hour|time_period|
# +-------------------+----------+-----------+
# |2019-09-30 17:00:00|17        |afternoon  |
# |2019-09-30 17:00:00|17        |afternoon  |
# |2019-09-30 17:00:01|17        |afternoon  |
# |2019-09-30 17:00:01|17        |afternoon  |
# |2019-09-30 17:00:04|17        |afternoon  |
# |2019-09-30 17:00:05|17        |afternoon  |
# |2019-09-30 17:00:08|17        |afternoon  |
# |2019-09-30 17:00:08|17        |afternoon  |
# |2019-09-30 17:00:10|17        |afternoon  |
# |2019-09-30 17:00:11|17        |afternoon  |
# +-------------------+----------+-----------+
# only showing top 10 rows

# %%
p25 = 64.78
p75 = 357.77

df_part = df_part.withColumn(
    "price_range",
    when(col("price") <= p25, "low")
    .when((col("price") > p25) & (col("price") <= p75), "medium")
    .when(col("price") > p75, "high")
    .otherwise("unknown")
)

df_part.select("price", "price_range").show(10, truncate=False)
# Out:
# +-------+-----------+
# |price  |price_range|
# +-------+-----------+
# |35.79  |low        |
# |33.2   |low        |
# |543.1  |high       |
# |251.74 |medium     |
# |1081.98|high       |
# |908.62 |high       |
# |380.96 |high       |
# |41.16  |low        |
# |102.71 |medium     |
# |566.01 |high       |
# +-------+-----------+
# only showing top 10 rows

# %%
df_part.select(
    "event_type",
    "category_code",
    "category_group",
    "price",
    "price_range",
    "event_time",
    "event_hour",
    "time_period"
).show(20, truncate=False)
# Out:
# +----------+-----------------------------------+--------------+-------+-----------+-------------------+----------+-----------+
# |event_type|category_code                      |category_group|price  |price_range|event_time         |event_hour|time_period|
# +----------+-----------------------------------+--------------+-------+-----------+-------------------+----------+-----------+
# |view      |NULL                               |unknown       |35.79  |low        |2019-09-30 17:00:00|17        |afternoon  |
# |view      |appliances.environment.water_heater|appliances    |33.2   |low        |2019-09-30 17:00:00|17        |afternoon  |
# |view      |furniture.living_room.sofa         |furniture     |543.1  |high       |2019-09-30 17:00:01|17        |afternoon  |
# |view      |computers.notebook                 |computers     |251.74 |medium     |2019-09-30 17:00:01|17        |afternoon  |
# |view      |electronics.smartphone             |electronics   |1081.98|high       |2019-09-30 17:00:04|17        |afternoon  |
# |view      |computers.desktop                  |computers     |908.62 |high       |2019-09-30 17:00:05|17        |afternoon  |
# |view      |NULL                               |unknown       |380.96 |high       |2019-09-30 17:00:08|17        |afternoon  |
# |view      |NULL                               |unknown       |41.16  |low        |2019-09-30 17:00:08|17        |afternoon  |
# |view      |apparel.shoes.keds                 |apparel       |102.71 |medium     |2019-09-30 17:00:10|17        |afternoon  |
# |view      |electronics.smartphone             |electronics   |566.01 |high       |2019-09-30 17:00:11|17        |afternoon  |
# |view      |appliances.kitchen.microwave       |appliances    |51.46  |low        |2019-09-30 17:00:11|17        |afternoon  |
# |view      |electronics.smartphone             |electronics   |900.64 |high       |2019-09-30 17:00:11|17        |afternoon  |
# |view      |appliances.environment.water_heater|appliances    |102.38 |medium     |2019-09-30 17:00:13|17        |afternoon  |
# |view      |NULL                               |unknown       |35.79  |low        |2019-09-30 17:00:15|17        |afternoon  |
# |view      |furniture.bedroom.bed              |furniture     |93.18  |medium     |2019-09-30 17:00:16|17        |afternoon  |
# |view      |NULL                               |unknown       |357.79 |high       |2019-09-30 17:00:17|17        |afternoon  |
# |view      |electronics.video.tv               |electronics   |193.03 |medium     |2019-09-30 17:00:18|17        |afternoon  |
# |view      |appliances.kitchen.mixer           |appliances    |58.95  |low        |2019-09-30 17:00:18|17        |afternoon  |
# |view      |computers.notebook                 |computers     |580.89 |high       |2019-09-30 17:00:19|17        |afternoon  |
# |view      |electronics.smartphone             |electronics   |1747.79|high       |2019-09-30 17:00:19|17        |afternoon  |
# +----------+-----------------------------------+--------------+-------+-----------+-------------------+----------+-----------+
# only showing top 20 rows

# %%
df_part.groupBy("event_type") \
    .count() \
    .withColumn("probability", col("count") / lit(num_rows)) \
    .withColumn("percentage", col("probability") * 100) \
    .orderBy(desc("count")) \
    .show(truncate=False)
# Out:
# +----------+--------+--------------------+------------------+
# |event_type|count   |probability         |percentage        |
# +----------+--------+--------------------+------------------+
# |view      |40779399|0.9606734132470853  |96.06734132470854 |
# |cart      |926516  |0.021826689700552883|2.182668970055288 |
# |purchase  |742849  |0.01749989705236176 |1.7499897052361761|
# +----------+--------+--------------------+------------------+

# %%
df_part.groupBy("category_group") \
    .count() \
    .withColumn("probability", col("count") / lit(num_rows)) \
    .withColumn("percentage", col("probability") * 100) \
    .orderBy(desc("count")) \
    .show(20, truncate=False)
# Out:
# +--------------+--------+---------------------+--------------------+
# |category_group|count   |probability          |percentage          |
# +--------------+--------+---------------------+--------------------+
# |electronics   |16135623|0.3801199723977829   |38.01199723977829   |
# |unknown       |13515609|0.3183981752684248   |31.839817526842477  |
# |appliances    |4967294 |0.11701857797320082  |11.701857797320082  |
# |computers     |2324217 |0.05475346702674311  |5.475346702674311   |
# |apparel       |1542924 |0.03634791345161428  |3.634791345161428   |
# |furniture     |1247160 |0.029380360756793768 |2.938036075679377   |
# |auto          |1013115 |0.02386677265797421  |2.386677265797421   |
# |construction  |730834  |0.01721684994173211  |1.7216849941732109  |
# |kids          |520619  |0.012264644501781018 |1.2264644501781017  |
# |accessories   |238238  |0.005612366004343495 |0.5612366004343495  |
# |sport         |176616  |0.0041606865161020945|0.41606865161020945 |
# |medicine      |14806   |3.4879696379381034E-4|0.034879696379381035|
# |country_yard  |14089   |3.319060126226526E-4 |0.03319060126226526 |
# |stationery    |7620    |1.7951052709096549E-4|0.017951052709096547|
# +--------------+--------+---------------------+--------------------+

# %%
df_part.groupBy("price_range") \
    .count() \
    .withColumn("probability", col("count") / lit(num_rows)) \
    .withColumn("percentage", col("probability") * 100) \
    .orderBy(desc("count")) \
    .show(truncate=False)
# Out:
# +-----------+--------+-------------------+------------------+
# |price_range|count   |probability        |percentage        |
# +-----------+--------+-------------------+------------------+
# |medium     |21234978|0.5002496185754667 |50.02496185754667 |
# |high       |10700699|0.2520850548204419 |25.208505482044192|
# |low        |10513087|0.24766532660409146|24.766532660409148|
# +-----------+--------+-------------------+------------------+

# %%
df_part.groupBy("time_period") \
    .count() \
    .withColumn("probability", col("count") / lit(num_rows)) \
    .withColumn("percentage", col("probability") * 100) \
    .orderBy(desc("count")) \
    .show(truncate=False)
# Out:
# +-----------+--------+-------------------+------------------+
# |time_period|count   |probability        |percentage        |
# +-----------+--------+-------------------+------------------+
# |morning    |15927856|0.37522543648149564|37.522543648149565|
# |night      |13706468|0.32289439570019046|32.28943957001905 |
# |evening    |9488727 |0.22353364635069234|22.353364635069234|
# |afternoon  |3325713 |0.07834652146762153|7.834652146762153 |
# +-----------+--------+-------------------+------------------+

# %%
partition_combinations = df_part.groupBy(
    "event_type",
    "category_group",
    "price_range",
    "time_period"
).count()

partition_combinations = partition_combinations.withColumn(
    "probability",
    col("count") / lit(num_rows)
).withColumn(
    "percentage",
    col("probability") * 100
)

partition_combinations.orderBy(desc("count")).show(50, truncate=False)
# Out:
# +----------+--------------+-----------+-----------+-------+---------------------+-------------------+
# |event_type|category_group|price_range|time_period|count  |probability          |percentage         |
# +----------+--------------+-----------+-----------+-------+---------------------+-------------------+
# |view      |electronics   |medium     |morning    |3026270|0.07129229958262154  |7.129229958262154  |
# |view      |electronics   |medium     |night      |2578533|0.06074459553168615  |6.074459553168615  |
# |view      |unknown       |medium     |morning    |2226350|0.052447934644221914 |5.244793464422191  |
# |view      |electronics   |high       |morning    |2212422|0.052119821439323887 |5.211982143932389  |
# |view      |unknown       |low        |morning    |2099047|0.04944895450901703  |4.944895450901703  |
# |view      |electronics   |high       |night      |1876077|0.04419626917759019  |4.419626917759019  |
# |view      |unknown       |medium     |night      |1816003|0.04278105718225388  |4.2781057182253885 |
# |view      |electronics   |medium     |evening    |1777739|0.041879641065638566 |4.187964106563856  |
# |view      |unknown       |low        |night      |1769849|0.04169376992931997  |4.169376992931997  |
# |view      |unknown       |medium     |evening    |1300494|0.0306367930995588   |3.06367930995588   |
# |view      |unknown       |low        |evening    |1291716|0.030430002626224875 |3.0430002626224875 |
# |view      |electronics   |high       |evening    |1239531|0.029200638209395214 |2.9200638209395215 |
# |view      |appliances    |medium     |morning    |957797 |0.022563601616292055 |2.2563601616292055 |
# |view      |appliances    |medium     |night      |900929 |0.021223915966080895 |2.1223915966080895 |
# |view      |unknown       |high       |morning    |694385 |0.016358191253813655 |1.6358191253813654 |
# |view      |appliances    |medium     |evening    |626526 |0.014759581692413941 |1.4759581692413941 |
# |view      |electronics   |medium     |afternoon  |582244 |0.013716394663458281 |1.3716394663458282 |
# |view      |unknown       |high       |night      |559182 |0.013173104404170638 |1.3173104404170637 |
# |view      |electronics   |high       |afternoon  |511376 |0.012046899645888395 |1.2046899645888394 |
# |view      |electronics   |low        |morning    |469064 |0.011050121506482498 |1.1050121506482498 |
# |view      |unknown       |low        |afternoon  |467144 |0.011004890507530443 |1.1004890507530443 |
# |view      |unknown       |medium     |afternoon  |466246 |0.010983735592395577 |1.0983735592395576 |
# |view      |appliances    |low        |morning    |458023 |0.010790019704696232 |1.0790019704696232 |
# |view      |appliances    |low        |night      |450016 |0.010601392304378992 |1.0601392304378991 |
# |view      |computers     |high       |morning    |441170 |0.010392999899832183 |1.0392999899832183 |
# |view      |unknown       |high       |evening    |397762 |0.00937040239852449  |0.9370402398524489 |
# |view      |electronics   |low        |night      |388114 |0.009143116628790417 |0.9143116628790418 |
# |view      |computers     |high       |night      |369609 |0.00870717931857804  |0.870717931857804  |
# |view      |apparel       |medium     |morning    |359420 |0.008467148772576746 |0.8467148772576747 |
# |view      |appliances    |high       |morning    |326223 |0.007685100089133337 |0.7685100089133338 |
# |view      |appliances    |low        |evening    |318666 |0.007507073704195486 |0.7507073704195486 |
# |view      |computers     |medium     |morning    |295647 |0.006964796430821873 |0.6964796430821872 |
# |view      |furniture     |medium     |morning    |289699 |0.006824674565318321 |0.682467456531832  |
# |view      |appliances    |high       |night      |275980 |0.00650148494311872  |0.650148494311872  |
# |view      |computers     |medium     |night      |268945 |0.00633575573602096  |0.6335755736020959 |
# |view      |electronics   |low        |evening    |267126 |0.006292904076076278 |0.6292904076076278 |
# |view      |apparel       |medium     |night      |267008 |0.006290124254265683 |0.6290124254265683 |
# |view      |apparel       |low        |morning    |262451 |0.006182771305190417 |0.6182771305190418 |
# |view      |auto          |medium     |morning    |256596 |0.006044840316198606 |0.6044840316198605 |
# |view      |computers     |high       |evening    |240550 |0.005666831665581594 |0.5666831665581594 |
# |view      |furniture     |medium     |night      |229994 |0.005418155402593112 |0.5418155402593111 |
# |view      |apparel       |low        |night      |203019 |0.004782683425128703 |0.4782683425128703 |
# |view      |auto          |medium     |night      |202179 |0.00476289486308718  |0.476289486308718  |
# |view      |appliances    |high       |evening    |191929 |0.004521427290556682 |0.45214272905566816|
# |view      |computers     |medium     |evening    |182196 |0.004292139106806502 |0.42921391068065023|
# |view      |apparel       |medium     |evening    |175116 |0.0041253497981708015|0.41253497981708015|
# |cart      |electronics   |medium     |night      |169999 |0.0040048044744011866|0.4004804474401187 |
# |view      |furniture     |medium     |evening    |157205 |0.0037034058282592163|0.37034058282592164|
# |view      |construction  |medium     |morning    |157176 |0.0037027226517125445|0.37027226517125444|
# |view      |appliances    |medium     |afternoon  |156241 |0.0036806960975353724|0.36806960975353725|
# +----------+--------------+-----------+-----------+-------+---------------------+-------------------+
# only showing top 50 rows

# %%
# Guardar las principales combinaciones de particionamiento
top_partition_combinations = partition_combinations.orderBy(desc("count")).limit(20)

top_partition_combinations_pd = top_partition_combinations.toPandas()
top_partition_combinations_pd
# Out:
#    event_type category_group price_range time_period    count  probability  \
# 0        view    electronics      medium     morning  3026270     0.071292
# 1        view    electronics      medium       night  2578533     0.060745
# 2        view        unknown      medium     morning  2226350     0.052448
# 3        view    electronics        high     morning  2212422     0.052120
# 4        view        unknown         low     morning  2099047     0.049449
# 5        view    electronics        high       night  1876077     0.044196
# 6        view        unknown      medium       night  1816003     0.042781
# 7        view    electronics      medium     evening  1777739     0.041880
# 8        view        unknown         low       night  1769849     0.041694
# 9        view        unknown      medium     evening  1300494     0.030637
# 10       view        unknown         low     evening  1291716     0.030430
# 11       view    electronics        high     evening  1239531     0.029201
# 12       view     appliances      medium     morning   957797     0.022564
# 13       view     appliances      medium       night   900929     0.021224
# 14       view        unknown        high     morning   694385     0.016358
# 15       view     appliances      medium     evening   626526     0.014760
# 16       view    electronics      medium   afternoon   582244     0.013716
# 17       view        unknown        high       night   559182     0.013173
# 18       view    electronics        high   afternoon   511376     0.012047
# 19       view    electronics         low     morning   469064     0.011050
#
#     percentage
# 0     7.129230
# 1     6.074460
# 2     5.244793
# 3     5.211982
# 4     4.944895
# 5     4.419627
# 6     4.278106
# 7     4.187964
# 8     4.169377
# 9     3.063679
# 10    3.043000
# 11    2.920064
# 12    2.256360
# 13    2.122392
# 14    1.635819
# 15    1.475958
# 16    1.371639
# 17    1.317310
# 18    1.204690
# 19    1.105012

# %% [markdown]
# ## Extracción de muestras de ejemplo por regla de particionamiento
#
# En esta sección se muestran ejemplos de extracción de registros que cumplen con reglas específicas de particionamiento. Cada regla se define por la combinación de cuatro variables: `event_type`, `category_group`, `price_range` y `time_period`.
#
# El objetivo de esta etapa no es construir todavía la muestra final de entrenamiento o prueba, sino comprobar que el código permite recuperar correctamente subconjuntos de la base de datos original D de acuerdo con las reglas definidas en la etapa de particionamiento.

# %%
def extraer_muestra_particion(event_type, category_group, price_range, time_period, n=10):
    """
    Filtra la base particionada usando una regla de particionamiento
    y muestra una muestra de ejemplo de n registros.
    """
    
    particion = df_part.filter(
        (col("event_type") == event_type) &
        (col("category_group") == category_group) &
        (col("price_range") == price_range) &
        (col("time_period") == time_period)
    )
    
    total_registros = particion.count()
    
    print("Regla de particionamiento:")
    print(f"event_type = {event_type}")
    print(f"category_group = {category_group}")
    print(f"price_range = {price_range}")
    print(f"time_period = {time_period}")
    print(f"Total de registros en la partición: {total_registros:,}")
    
    particion.show(n, truncate=False)
    
    return particion

# %%
#Ejemplo 1
muestra_p1 = extraer_muestra_particion(
    event_type="view",
    category_group="electronics",
    price_range="medium",
    time_period="morning",
    n=10
)
# Out:
# Regla de particionamiento:
# event_type = view
# category_group = electronics
# price_range = medium
# time_period = morning
# Total de registros en la partición: 3,026,270
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code         |brand  |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 06:00:00|view      |5100577   |2053013553341792533|electronics.clocks    |samsung|295.9 |518665525|cd504a29-cbfd-4640-bea4-27b7684b6eda|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |1004566   |2053013555631882655|electronics.smartphone|huawei |175.68|512568659|f51ba00a-bfa6-4b4a-9456-cc3f732b3784|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |1005157   |2053013555631882655|electronics.smartphone|xiaomi |282.89|515072785|080eb393-91e0-4b6b-bd09-224d940c95df|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |1004834   |2053013555631882655|electronics.smartphone|samsung|174.39|514280488|38b90adc-378c-4de2-bdb0-17fafd77c869|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |1005098   |2053013555631882655|electronics.smartphone|samsung|154.33|537458679|0bf525b0-b26f-421c-a6c1-ad6415fb8a61|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:01|view      |1004934   |2053013555631882655|electronics.smartphone|vivo   |231.64|540325462|684437c6-f4c9-49b0-bbf7-14fb5dbd3796|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:01|view      |1801940   |2053013554415534427|electronics.video.tv  |haier  |244.51|542388645|07cc9c86-b1cb-43d6-89cf-105ac089dcc7|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:01|view      |1005064   |2053013555631882655|electronics.smartphone|xiaomi |208.23|513597570|da43ec87-9c54-44dd-bf5b-8a18f43bf9ee|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:01|view      |1003992   |2053013555631882655|electronics.smartphone|lg     |216.2 |527540630|1dadbb52-5e57-4e6b-9a65-d7fb194eacfa|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:01|view      |1004209   |2053013555631882655|electronics.smartphone|samsung|90.07 |514744528|266fed09-7664-4e16-bef5-19e0e93eea56|electronics   |6         |morning    |medium     |
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 10 rows

# %%
#Ejemplo 2
muestra_p2 = extraer_muestra_particion(
    event_type="view",
    category_group="electronics",
    price_range="medium",
    time_period="night",
    n=10
)
# Out:
# Regla de particionamiento:
# event_type = view
# category_group = electronics
# price_range = medium
# time_period = night
# Total de registros en la partición: 2,578,533
# +-------------------+----------+----------+-------------------+---------------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code              |brand  |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+---------------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 00:00:00|view      |1005003   |2053013555631882655|electronics.smartphone     |huawei |258.18|512818021|9538bb83-1b8c-4bb2-bba4-eaeafc667368|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:01|view      |1004785   |2053013555631882655|electronics.smartphone     |huawei |278.54|555515172|f1232a9b-8dc8-4498-9c4b-93a5c89ebff7|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:01|view      |1004788   |2053013555631882655|electronics.smartphone     |xiaomi |133.67|517196620|d852e1c3-be17-4adc-bc51-6db231f7f72c|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:02|view      |2300222   |2053013560530830019|electronics.camera.video   |sony   |334.6 |537424620|210e83d4-a55a-4e6c-86a8-8529ff2f5174|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:02|view      |5100337   |2053013553341792533|electronics.clocks         |apple  |311.84|547414608|c46d8fab-173f-47cf-bbc5-ed0e4a166278|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:02|view      |1004781   |2053013555631882655|electronics.smartphone     |huawei |278.24|520170863|6f337f79-311b-4d42-80e4-606fec9e45c1|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:03|view      |4804056   |2053013554658804075|electronics.audio.headphone|apple  |161.93|529037410|b63771fa-1ef8-421f-ba62-beec010e0785|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:03|view      |1801830   |2053013554415534427|electronics.video.tv       |yasin  |158.04|538536402|7ee46a59-f0ea-44ba-b9f8-a09a3303d99a|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:03|view      |1004209   |2053013555631882655|electronics.smartphone     |samsung|95.21 |555379652|a3297c46-1185-4954-96dc-3bf2d5deabd9|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:03|view      |1801723   |2053013554415534427|electronics.video.tv       |tcl    |145.13|515881990|48ae3259-6c5f-4551-9ebe-b67bf84c3865|electronics   |0         |night      |medium     |
# +-------------------+----------+----------+-------------------+---------------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 10 rows

# %%
#Ejemplo 3
muestra_p3 = extraer_muestra_particion(
    event_type="view",
    category_group="electronics",
    price_range="high",
    time_period="morning",
    n=10
)
# Out:
# Regla de particionamiento:
# event_type = view
# category_group = electronics
# price_range = high
# time_period = morning
# Total de registros en la partición: 2,212,422
# +-------------------+----------+----------+-------------------+----------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code         |brand  |price  |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+----------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 06:00:00|view      |21406579  |2053013561579406073|electronics.clocks    |tissot |377.87 |541562450|6053865e-4149-4cfc-b239-deb83abfee06|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:00|view      |1004385   |2053013555631882655|electronics.smartphone|oppo   |776.08 |526667511|1ae3a2fc-b0d2-4664-957d-9f04cde4e8cd|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:00|view      |1005115   |2053013555631882655|electronics.smartphone|apple  |975.56 |517293350|4fa56e74-f80a-4da7-8aa9-7c7055a196d8|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:00|view      |1004873   |2053013555631882655|electronics.smartphone|samsung|388.43 |549240909|b6e37c52-24d1-4e0b-8736-11d40d913d60|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:01|view      |1003318   |2053013555631882655|electronics.smartphone|apple  |1070.77|542330859|78796455-1296-4b79-98fc-b24cbc755333|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:01|view      |1004237   |2053013555631882655|electronics.smartphone|apple  |1093.93|555634832|b49fdcf1-a58f-47a0-a465-551d69261e7d|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:01|view      |1005105   |2053013555631882655|electronics.smartphone|apple  |1415.48|555635078|fbd913e4-9c98-4a72-a4db-88d67ed563e3|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:01|view      |1005105   |2053013555631882655|electronics.smartphone|apple  |1415.48|513620066|99d231b6-644d-4875-89f7-c596c384c5be|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:01|view      |1004958   |2053013555631882655|electronics.smartphone|xiaomi |360.07 |547323292|210c7892-f417-48ac-a960-a35e5c419f7b|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:01|view      |1005122   |2053013555631882655|electronics.smartphone|apple  |1027.05|518872791|bac796ba-c593-46bc-91ca-ab34171aaa3c|electronics   |6         |morning    |high       |
# +-------------------+----------+----------+-------------------+----------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 10 rows

# %%
#Ejemplo 4
muestra_purchase = extraer_muestra_particion(
    event_type="purchase",
    category_group="electronics",
    price_range="medium",
    time_period="morning",
    n=10
)
# Out:
# Regla de particionamiento:
# event_type = purchase
# category_group = electronics
# price_range = medium
# time_period = morning
# Total de registros en la partición: 64,467
# +-------------------+----------+----------+-------------------+--------------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code             |brand  |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+--------------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 06:00:01|purchase  |1004768   |2053013555631882655|electronics.smartphone    |samsung|253.29|548837247|bb7c461b-5c25-44a2-b462-281dbb17e709|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:12|purchase  |1004870   |2053013555631882655|electronics.smartphone    |samsung|286.85|513623471|841a4df9-ce8c-4447-931c-4cd8c6593c89|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:18|purchase  |1004857   |2053013555631882655|electronics.smartphone    |samsung|130.73|545606103|13b91e5e-7f09-42a4-83b9-fd5294256ab3|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:29|purchase  |1004857   |2053013555631882655|electronics.smartphone    |samsung|130.73|555634264|9ec56264-2f76-4b2a-ae53-d42765698c5d|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:31|purchase  |1005007   |2053013555631882655|electronics.smartphone    |xiaomi |100.12|517079560|43a4d388-b124-4e68-91f8-82d2ec8fb370|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:37|purchase  |1004767   |2053013555631882655|electronics.smartphone    |samsung|254.19|542528775|d61624f7-1685-4672-845a-2e1e57692e54|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:39|purchase  |14100113  |2053013557670314521|electronics.audio.acoustic|fender |119.69|549414804|b5fc91cb-87d4-46cc-a813-2ee610c6f3c9|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:40|purchase  |1004749   |2053013555631882655|electronics.smartphone    |samsung|203.35|555625803|c06c45c4-7361-4232-920e-1712e206f115|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:42|purchase  |1005103   |2053013555631882655|electronics.smartphone    |xiaomi |100.12|543737917|50450b63-fc74-4d32-a146-822713afb52e|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:45|purchase  |1004496   |2053013555631882655|electronics.smartphone    |meizu  |71.79 |554941286|1ec34a57-f62d-4b06-88ab-34d060b071c3|electronics   |6         |morning    |medium     |
# +-------------------+----------+----------+-------------------+--------------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 10 rows

# %%
#Extraer las 10 reglas de particionamiento más frecuentes
top_10_rules = partition_combinations.orderBy(desc("count")).limit(10).collect()

for i, rule in enumerate(top_10_rules, start=1):
    print("=" * 80)
    print(f"Muestra de ejemplo para la partición P{i}")
    
    muestra = df_part.filter(
        (col("event_type") == rule["event_type"]) &
        (col("category_group") == rule["category_group"]) &
        (col("price_range") == rule["price_range"]) &
        (col("time_period") == rule["time_period"])
    )
    
    print(f"event_type: {rule['event_type']}")
    print(f"category_group: {rule['category_group']}")
    print(f"price_range: {rule['price_range']}")
    print(f"time_period: {rule['time_period']}")
    print(f"Registros en la partición: {rule['count']:,}")
    print(f"Probabilidad: {rule['probability']:.4f}")
    print(f"Porcentaje: {rule['percentage']:.2f}%")
    
    muestra.show(5, truncate=False)
# Out:
# ================================================================================
# Muestra de ejemplo para la partición P1
# event_type: view
# category_group: electronics
# price_range: medium
# time_period: morning
# Registros en la partición: 3,026,270
# Probabilidad: 0.0713
# Porcentaje: 7.13%
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code         |brand  |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 06:00:00|view      |5100577   |2053013553341792533|electronics.clocks    |samsung|295.9 |518665525|cd504a29-cbfd-4640-bea4-27b7684b6eda|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |1004566   |2053013555631882655|electronics.smartphone|huawei |175.68|512568659|f51ba00a-bfa6-4b4a-9456-cc3f732b3784|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |1005157   |2053013555631882655|electronics.smartphone|xiaomi |282.89|515072785|080eb393-91e0-4b6b-bd09-224d940c95df|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |1004834   |2053013555631882655|electronics.smartphone|samsung|174.39|514280488|38b90adc-378c-4de2-bdb0-17fafd77c869|electronics   |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |1005098   |2053013555631882655|electronics.smartphone|samsung|154.33|537458679|0bf525b0-b26f-421c-a6c1-ad6415fb8a61|electronics   |6         |morning    |medium     |
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P2
# event_type: view
# category_group: electronics
# price_range: medium
# time_period: night
# Registros en la partición: 2,578,533
# Probabilidad: 0.0607
# Porcentaje: 6.07%
# +-------------------+----------+----------+-------------------+------------------------+------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code           |brand |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+------------------------+------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 00:00:00|view      |1005003   |2053013555631882655|electronics.smartphone  |huawei|258.18|512818021|9538bb83-1b8c-4bb2-bba4-eaeafc667368|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:01|view      |1004785   |2053013555631882655|electronics.smartphone  |huawei|278.54|555515172|f1232a9b-8dc8-4498-9c4b-93a5c89ebff7|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:01|view      |1004788   |2053013555631882655|electronics.smartphone  |xiaomi|133.67|517196620|d852e1c3-be17-4adc-bc51-6db231f7f72c|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:02|view      |2300222   |2053013560530830019|electronics.camera.video|sony  |334.6 |537424620|210e83d4-a55a-4e6c-86a8-8529ff2f5174|electronics   |0         |night      |medium     |
# |2019-10-01 00:00:02|view      |5100337   |2053013553341792533|electronics.clocks      |apple |311.84|547414608|c46d8fab-173f-47cf-bbc5-ed0e4a166278|electronics   |0         |night      |medium     |
# +-------------------+----------+----------+-------------------+------------------------+------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P3
# event_type: view
# category_group: unknown
# price_range: medium
# time_period: morning
# Registros en la partición: 2,226,350
# Probabilidad: 0.0524
# Porcentaje: 5.24%
# +-------------------+----------+----------+-------------------+-------------+--------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code|brand   |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+-------------+--------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 06:00:00|view      |12700747  |2053013553559896355|NULL         |michelin|154.44|512833339|1b7869e3-b9ce-efa9-513f-1e8d3d59bbd5|unknown       |6         |morning    |medium     |
# |2019-10-01 06:00:00|view      |8200303   |2053013555413778833|NULL         |NULL    |77.2  |549834757|9f28ec8f-2964-4030-9580-01533b004992|unknown       |6         |morning    |medium     |
# |2019-10-01 06:00:01|view      |2601426   |2053013563970159485|NULL         |flama   |127.92|555625412|40fee3f2-9b98-4fdb-a41a-1a0ff30e26be|unknown       |6         |morning    |medium     |
# |2019-10-01 06:00:01|view      |28101205  |2053013564918072245|NULL         |erkaplan|105.79|512601095|43a3aa4f-788b-44c8-ad87-b16f13e470ce|unknown       |6         |morning    |medium     |
# |2019-10-01 06:00:02|view      |22200014  |2053013558785999453|NULL         |NULL    |113.59|514482335|a6096dcf-0a26-4f26-8c4b-eff5c784498a|unknown       |6         |morning    |medium     |
# +-------------------+----------+----------+-------------------+-------------+--------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P4
# event_type: view
# category_group: electronics
# price_range: high
# time_period: morning
# Registros en la partición: 2,212,422
# Probabilidad: 0.0521
# Porcentaje: 5.21%
# +-------------------+----------+----------+-------------------+----------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code         |brand  |price  |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+----------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 06:00:00|view      |21406579  |2053013561579406073|electronics.clocks    |tissot |377.87 |541562450|6053865e-4149-4cfc-b239-deb83abfee06|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:00|view      |1004385   |2053013555631882655|electronics.smartphone|oppo   |776.08 |526667511|1ae3a2fc-b0d2-4664-957d-9f04cde4e8cd|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:00|view      |1005115   |2053013555631882655|electronics.smartphone|apple  |975.56 |517293350|4fa56e74-f80a-4da7-8aa9-7c7055a196d8|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:00|view      |1004873   |2053013555631882655|electronics.smartphone|samsung|388.43 |549240909|b6e37c52-24d1-4e0b-8736-11d40d913d60|electronics   |6         |morning    |high       |
# |2019-10-01 06:00:01|view      |1003318   |2053013555631882655|electronics.smartphone|apple  |1070.77|542330859|78796455-1296-4b79-98fc-b24cbc755333|electronics   |6         |morning    |high       |
# +-------------------+----------+----------+-------------------+----------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P5
# event_type: view
# category_group: unknown
# price_range: low
# time_period: morning
# Registros en la partición: 2,099,047
# Probabilidad: 0.0494
# Porcentaje: 4.94%
# +-------------------+----------+----------+-------------------+-------------+--------+-----+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code|brand   |price|user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+-------------+--------+-----+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 06:00:00|view      |5300245   |2053013563173241677|NULL         |philips |28.29|555627934|01fc3154-938c-47ba-934a-19925a42f339|unknown       |6         |morning    |low        |
# |2019-10-01 06:00:00|view      |12711598  |2053013553559896355|NULL         |triangle|56.11|529391455|8621cef4-c25e-47df-ac36-03c457d89848|unknown       |6         |morning    |low        |
# |2019-10-01 06:00:00|view      |12704985  |2053013553559896355|NULL         |maxxis  |51.22|554654005|79533828-6ef9-29b9-b7da-1daa90b3cee8|unknown       |6         |morning    |low        |
# |2019-10-01 06:00:01|view      |37200165  |2075962341748376288|NULL         |crockid |8.24 |546419884|abb5f0d1-31f9-40a2-acff-14d25d369d47|unknown       |6         |morning    |low        |
# |2019-10-01 06:00:02|view      |15200519  |2053013553484398879|NULL         |bars    |53.79|513004892|785521ca-9eac-4a97-aae0-9500ffc0d568|unknown       |6         |morning    |low        |
# +-------------------+----------+----------+-------------------+-------------+--------+-----+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P6
# event_type: view
# category_group: electronics
# price_range: high
# time_period: night
# Registros en la partición: 1,876,077
# Probabilidad: 0.0442
# Porcentaje: 4.42%
# +-------------------+----------+----------+-------------------+---------------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code              |brand  |price  |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+---------------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 00:00:00|view      |4804110   |2053013554658804075|electronics.audio.headphone|sony   |900.9  |544349091|9a9fdfc7-bdd2-4872-96cf-c0634401928e|electronics   |0         |night      |high       |
# |2019-10-01 00:00:00|view      |1005105   |2053013555631882655|electronics.smartphone     |apple  |1415.48|546103688|04ab7bd9-b234-45f7-be78-74c203ed4451|electronics   |0         |night      |high       |
# |2019-10-01 00:00:00|view      |1801382   |2053013554415534427|electronics.video.tv       |toshiba|511.98 |551470148|1a07eed6-be0a-4f85-8e1b-6ae362806655|electronics   |0         |night      |high       |
# |2019-10-01 00:00:01|view      |1003965   |2053013555631882655|electronics.smartphone     |samsung|720.46 |513619406|b4a46186-3406-cab9-cc3b-53e0f6c50e16|electronics   |0         |night      |high       |
# |2019-10-01 00:00:01|view      |1004059   |2053013555631882655|electronics.smartphone     |xiaomi |360.34 |514315124|f781d583-2a01-470e-8e17-9221584396af|electronics   |0         |night      |high       |
# +-------------------+----------+----------+-------------------+---------------------------+-------+-------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P7
# event_type: view
# category_group: unknown
# price_range: medium
# time_period: night
# Registros en la partición: 1,816,003
# Probabilidad: 0.0428
# Porcentaje: 4.28%
# +-------------------+----------+----------+-------------------+-------------+---------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code|brand    |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+-------------+---------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 00:00:00|view      |16600151  |2053013560287560373|NULL         |rivertoys|226.52|516352657|7a2ed5e8-c9cd-44a3-a25e-7890a7c799eb|unknown       |0         |night      |medium     |
# |2019-10-01 00:00:00|view      |28100243  |2053013564918072245|NULL         |NULL     |66.41 |519071006|38e5f10f-566f-491c-8585-0a63bb2db0ef|unknown       |0         |night      |medium     |
# |2019-10-01 00:00:01|view      |15200020  |2053013553484398879|NULL         |varta    |115.83|551724240|7359b65a-b9ac-4718-92cf-aab40b410d44|unknown       |0         |night      |medium     |
# |2019-10-01 00:00:01|view      |2602216   |2053013563970159485|NULL         |shivaki  |167.29|554894997|b9e8cfba-682b-442c-9590-f1e1e0c89742|unknown       |0         |night      |medium     |
# |2019-10-01 00:00:02|view      |3500009   |2053013555287949705|NULL         |bosch    |277.97|517413325|77f82b30-3421-4e9c-9e5d-7837432ee82d|unknown       |0         |night      |medium     |
# +-------------------+----------+----------+-------------------+-------------+---------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P8
# event_type: view
# category_group: electronics
# price_range: medium
# time_period: evening
# Registros en la partición: 1,777,739
# Probabilidad: 0.0419
# Porcentaje: 4.19%
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code         |brand  |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-09-30 18:03:08|view      |5100376   |2053013553341792533|electronics.clocks    |xiaomi |68.01 |541508474|3ec3e92b-7847-45d7-b9fb-6f42ee9b3dc7|electronics   |18        |evening    |medium     |
# |2019-09-30 18:06:49|view      |1004767   |2053013555631882655|electronics.smartphone|samsung|254.82|552286125|c0565272-0858-4b5f-b173-42adc90aeda5|electronics   |18        |evening    |medium     |
# |2019-09-30 18:06:56|view      |1004839   |2053013555631882655|electronics.smartphone|oppo   |179.39|477121012|413b498a-71d5-49fa-b896-1761ab981917|electronics   |18        |evening    |medium     |
# |2019-09-30 18:09:16|view      |1004857   |2053013555631882655|electronics.smartphone|samsung|130.73|555338559|868ef71b-dc97-41da-9579-63d746899950|electronics   |18        |evening    |medium     |
# |2019-09-30 18:13:05|view      |1004795   |2053013555631882655|electronics.smartphone|xiaomi |244.25|555111746|bbf3ba8e-8aeb-4ae7-b2b1-54e49f682501|electronics   |18        |evening    |medium     |
# +-------------------+----------+----------+-------------------+----------------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P9
# event_type: view
# category_group: unknown
# price_range: low
# time_period: night
# Registros en la partición: 1,769,849
# Probabilidad: 0.0417
# Porcentaje: 4.17%
# +-------------------+----------+----------+-------------------+-------------+-------+-----+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code|brand  |price|user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+-------------+-------+-----+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-10-01 00:00:00|view      |32403455  |2053013566562238479|NULL         |elysium|7.46 |521074984|384ec672-cb10-4364-a87f-d556b4c646ae|unknown       |0         |night      |low        |
# |2019-10-01 00:00:00|view      |18001267  |2053013558525952589|NULL         |samsung|1.69 |518006959|be69d84c-dc0b-47ec-8dd4-90e1440cda45|unknown       |0         |night      |low        |
# |2019-10-01 00:00:00|view      |16500005  |2053013556462354899|NULL         |omron  |34.86|512837635|bc0c9242-6fdb-4593-a1cc-09cf0b80b69f|unknown       |0         |night      |low        |
# |2019-10-01 00:00:00|view      |38300153  |2078957452669223168|NULL         |NULL   |3.17 |519078297|aeceaca3-8b2b-4540-9a34-98cc9ff37f4e|unknown       |0         |night      |low        |
# |2019-10-01 00:00:00|view      |37900169  |2152167773222993940|NULL         |vega   |37.99|527108565|79661316-17d1-4cef-97e2-7a6acebbf8e4|unknown       |0         |night      |low        |
# +-------------------+----------+----------+-------------------+-------------+-------+-----+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows
# ================================================================================
# Muestra de ejemplo para la partición P10
# event_type: view
# category_group: unknown
# price_range: medium
# time_period: evening
# Registros en la partición: 1,300,494
# Probabilidad: 0.0306
# Porcentaje: 3.06%
# +-------------------+----------+----------+-------------------+-------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |event_time         |event_type|product_id|category_id        |category_code|brand  |price |user_id  |user_session                        |category_group|event_hour|time_period|price_range|
# +-------------------+----------+----------+-------------------+-------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# |2019-09-30 18:00:41|view      |12703406  |2053013553559896355|NULL         |maxxis |66.28 |512611210|a1523ae9-1591-133c-2eb0-6e2478b18bd5|unknown       |18        |evening    |medium     |
# |2019-09-30 18:09:29|view      |3300497   |2053013555355058573|NULL         |polaris|102.27|554585192|c659bf4e-5200-4858-933f-bac38697cc9e|unknown       |18        |evening    |medium     |
# |2019-09-30 18:13:00|view      |13100411  |2053013553526341921|NULL         |NULL   |101.21|538645409|bcf04da8-72ee-4b98-a2c0-03379ca46df3|unknown       |18        |evening    |medium     |
# |2019-09-30 18:20:39|view      |17300555  |2053013553853497655|NULL         |dior   |99.1  |555353307|7da30f95-14b8-45c5-a303-ed6429162c7b|unknown       |18        |evening    |medium     |
# |2019-09-30 18:22:12|view      |13100841  |2053013553526341921|NULL         |skad   |242.17|542718671|c10a9bd0-0e78-4934-bf22-09605462fe8e|unknown       |18        |evening    |medium     |
# +-------------------+----------+----------+-------------------+-------------+-------+------+---------+------------------------------------+--------------+----------+-----------+-----------+
# only showing top 5 rows

# %%
# Ejemplo de muestreo estratificado proporcional
# En esta etapa solo se muestra cómo se podría aplicar posteriormente.

sample_fraction = 0.001  # 0.1% de cada partición, ejemplo

sample_df = df_part.sampleBy(
    "event_type",
    fractions={
        "view": sample_fraction,
        "cart": sample_fraction,
        "purchase": sample_fraction
    },
    seed=42
)

sample_df.groupBy("event_type").count().show()
# Out:
# +----------+-----+
# |event_type|count|
# +----------+-----+
# |  purchase|  783|
# |      view|40927|
# |      cart|  892|
# +----------+-----+

# %%
from pyspark.sql.functions import concat_ws

# Crear una llave única de partición
df_part = df_part.withColumn(
    "partition_key",
    concat_ws(
        "_",
        "event_type",
        "category_group",
        "price_range",
        "time_period"
    )
)

df_part.select(
    "event_type",
    "category_group",
    "price_range",
    "time_period",
    "partition_key"
).show(10, truncate=False)
# Out:
# +----------+--------------+-----------+-----------+-------------------------------+
# |event_type|category_group|price_range|time_period|partition_key                  |
# +----------+--------------+-----------+-----------+-------------------------------+
# |view      |unknown       |low        |afternoon  |view_unknown_low_afternoon     |
# |view      |appliances    |low        |afternoon  |view_appliances_low_afternoon  |
# |view      |furniture     |high       |afternoon  |view_furniture_high_afternoon  |
# |view      |computers     |medium     |afternoon  |view_computers_medium_afternoon|
# |view      |electronics   |high       |afternoon  |view_electronics_high_afternoon|
# |view      |computers     |high       |afternoon  |view_computers_high_afternoon  |
# |view      |unknown       |high       |afternoon  |view_unknown_high_afternoon    |
# |view      |unknown       |low        |afternoon  |view_unknown_low_afternoon     |
# |view      |apparel       |medium     |afternoon  |view_apparel_medium_afternoon  |
# |view      |electronics   |high       |afternoon  |view_electronics_high_afternoon|
# +----------+--------------+-----------+-----------+-------------------------------+
# only showing top 10 rows

# %% [markdown]
# ## Técnica de muestreo propuesta
#
# Para la construcción de la muestra representativa M se propone utilizar muestreo estratificado proporcional por partición. Cada partición está definida por la combinación de `event_type`, `category_group`, `price_range` y `time_period`.
#
# La muestra se obtendrá seleccionando registros de cada partición de acuerdo con la proporción que dicha partición representa dentro de la población original. Esto permite conservar la estructura de la base D y reducir el riesgo de sesgo, especialmente porque el dataset presenta un fuerte desbalance entre eventos de visualización, carrito y compra.
